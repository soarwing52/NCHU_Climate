# %%
import numpy as np
import pandas as pd
import os

# %%
df_electricity = pd.read_csv("./electricity/total.csv")
df_population = pd.read_csv("./population/total.csv")

# %%
df = pd.merge(df_electricity, df_population, left_on=['鄉鎮名稱', '村里名稱'], right_on=['district', 'village'],how='outer')
df
# Out:
#      Unnamed: 0_x 鄉鎮名稱 村里名稱 用電量_2011 用電量_2012 用電量_2013 用電量_2014  Unnamed: 0_y  \
# 0             0.0  松山區  復盛里      590    17699     8950    11176          21.0
# 1             1.0  松山區  復勢里     1323     1338     1435     1349          22.0
# 2             2.0  松山區  福成里       --       --       --     1349          29.0
# 3             3.0  松山區  新聚里       10       --     3978       --          28.0
# 4             4.0  松山區  美仁里       11       --       --       --          16.0
# ..            ...  ...  ...      ...      ...      ...      ...           ...
# 452         452.0  北投區  文化里  1123429     1532  1052605   921753         422.0
# 453         453.0  北投區  長安里  1939118  1111207  1984064  1645260         436.0
# 454         454.0  北投區  智仁里  1606980   954363  1581995  1175993         444.0
# 455         455.0  北投區  中庸里  1376804  1266570  1405213   888589         421.0
# 456           NaN  NaN  NaN      NaN      NaN      NaN      NaN         256.0
#
#     district village  population_2011  population_2012  population_2013  \
# 0        松山區     復盛里           6935.0           6929.0           6858.0
# 1        松山區     復勢里           6638.0           6716.0           6709.0
# 2        松山區     福成里           2985.0           3043.0           3003.0
# 3        松山區     新聚里           8252.0           8339.0           8313.0
# 4        松山區     美仁里           3750.0           3731.0           3803.0
# ..       ...     ...              ...              ...              ...
# 452      北投區     文化里           4562.0           4558.0           4560.0
# 453      北投區     長安里           6211.0           6257.0           6345.0
# 454      北投區     智仁里           6445.0           6554.0           6585.0
# 455      北投區     中庸里           4565.0           4571.0           4614.0
# 456      萬華區     糖?里           5750.0           5764.0           5759.0
#
#      population_2014  population_2015
# 0             6857.0           6857.0
# 1             6615.0           6615.0
# 2             2983.0           2983.0
# 3             8379.0           8379.0
# 4             3840.0           3840.0
# ..               ...              ...
# 452           4622.0           4622.0
# 453           6429.0           6429.0
# 454           6648.0           6648.0
# 455           4591.0           4591.0
# 456           5783.0           5783.0
#
# [457 rows x 15 columns]

# %%
df['用電量_2011'] = pd.to_numeric(df['用電量_2011'], errors='coerce')
df['用電量_2012'] = pd.to_numeric(df['用電量_2012'], errors='coerce')
df['用電量_2013'] = pd.to_numeric(df['用電量_2013'], errors='coerce')
df['用電量_2014'] = pd.to_numeric(df['用電量_2014'], errors='coerce')

# %%
df['人均用電量_2011'] = df['用電量_2011'] / df['population_2011']
df['人均用電量_2012'] = df['用電量_2012'] / df['population_2012']
df['人均用電量_2013'] = df['用電量_2013'] / df['population_2013']
df['人均用電量_2014'] = df['用電量_2014'] / df['population_2014']

# %%
df.drop('Unnamed: 0_x', inplace=True, axis=1)
df.drop('Unnamed: 0_y', inplace=True, axis=1)
df.drop('district', inplace=True, axis=1)
df.drop('village', inplace=True, axis=1)
df.to_csv('avg_electricity.csv')

# %%
df.columns
# Out:
# Index(['鄉鎮名稱', '村里名稱', '用電量_2011', '用電量_2012', '用電量_2013', '用電量_2014',
#        'population_2011', 'population_2012', 'population_2013',
#        'population_2014', 'population_2015', '人均用電量_2011', '人均用電量_2012',
#        '人均用電量_2013', '人均用電量_2014'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 鄉鎮名稱                object
# 村里名稱                object
# 用電量_2011           float64
# 用電量_2012           float64
# 用電量_2013           float64
# 用電量_2014           float64
# population_2011    float64
# population_2012    float64
# population_2013    float64
# population_2014    float64
# population_2015    float64
# 人均用電量_2011         float64
# 人均用電量_2012         float64
# 人均用電量_2013         float64
# 人均用電量_2014         float64
# dtype: object

# %%
df
# Out:
#     鄉鎮名稱 村里名稱   用電量_2011   用電量_2012   用電量_2013   用電量_2014  population_2011  \
# 0    松山區  復盛里      590.0    17699.0     8950.0    11176.0           6935.0
# 1    松山區  復勢里     1323.0     1338.0     1435.0     1349.0           6638.0
# 2    松山區  福成里        NaN        NaN        NaN     1349.0           2985.0
# 3    松山區  新聚里       10.0        NaN     3978.0        NaN           8252.0
# 4    松山區  美仁里       11.0        NaN        NaN        NaN           3750.0
# ..   ...  ...        ...        ...        ...        ...              ...
# 452  北投區  文化里  1123429.0     1532.0  1052605.0   921753.0           4562.0
# 453  北投區  長安里  1939118.0  1111207.0  1984064.0  1645260.0           6211.0
# 454  北投區  智仁里  1606980.0   954363.0  1581995.0  1175993.0           6445.0
# 455  北投區  中庸里  1376804.0  1266570.0  1405213.0   888589.0           4565.0
# 456  NaN  NaN        NaN        NaN        NaN        NaN           5750.0
#
#      population_2012  population_2013  population_2014  population_2015  \
# 0             6929.0           6858.0           6857.0           6857.0
# 1             6716.0           6709.0           6615.0           6615.0
# 2             3043.0           3003.0           2983.0           2983.0
# 3             8339.0           8313.0           8379.0           8379.0
# 4             3731.0           3803.0           3840.0           3840.0
# ..               ...              ...              ...              ...
# 452           4558.0           4560.0           4622.0           4622.0
# 453           6257.0           6345.0           6429.0           6429.0
# 454           6554.0           6585.0           6648.0           6648.0
# 455           4571.0           4614.0           4591.0           4591.0
# 456           5764.0           5759.0           5783.0           5783.0
#
#      人均用電量_2011  人均用電量_2012  人均用電量_2013  人均用電量_2014
# 0      0.085076    2.554337    1.305045    1.629867
# 1      0.199307    0.199226    0.213892    0.203930
# 2           NaN         NaN         NaN    0.452229
# 3      0.001212         NaN    0.478528         NaN
# 4      0.002933         NaN         NaN         NaN
# ..          ...         ...         ...         ...
# 452  246.258001    0.336112  230.834430  199.427304
# 453  312.207052  177.594214  312.697242  255.912273
# 454  249.337471  145.615349  240.242217  176.894254
# 455  301.600000  277.088165  304.554183  193.550207
# 456         NaN         NaN         NaN         NaN
#
# [457 rows x 15 columns]
