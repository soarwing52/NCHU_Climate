# %%
import numpy as np
import pandas as pd
import os

# %%
df_electricity = pd.read_csv("../electricity/aug/total.csv")
df_population = pd.read_csv("../population/total.csv")

# %%
df = pd.merge(df_electricity, df_population, left_on=['鄉鎮名稱', '村里名稱'], right_on=['district', 'village'],how='outer')
df
# Out:
#      Unnamed: 0_x 鄉鎮名稱 村里名稱 用電量_2011 用電量_2012 用電量_2013 用電量_2014  Unnamed: 0_y  \
# 0             0.0  松山區  自強里  1463044  3491896  3723146  3581703          10.0
# 1             1.0  松山區  龍田里  1225510  2592077  2825239  2739252          31.0
# 2             2.0  松山區  復勢里  2858397  2828139  2997644  3031601          22.0
# 3             3.0  松山區  中華里  1602938  1557914  1730038  1739430           3.0
# 4             4.0  松山區  東勢里  1991162  1934795  2092437  2124598          13.0
# ..            ...  ...  ...      ...      ...      ...      ...           ...
# 452         452.0  北投區  大同里  2256325  2126623  2270003  2086341         417.0
# 453         453.0  北投區  一德里  2520536     3232  2648871  2569633         414.0
# 454         454.0  北投區  中央里  3264807  3114267  3340573  4123849         419.0
# 455         455.0  北投區  桃源里  1856212  1495717  1942503  1646348         441.0
# 456           NaN  NaN  NaN      NaN      NaN      NaN      NaN         256.0
#
#     district village  population_2011  population_2012  population_2013  \
# 0        松山區     自強里          10176.0          10183.0          10202.0
# 1        松山區     龍田里          11327.0          11284.0          11284.0
# 2        松山區     復勢里           6638.0           6716.0           6709.0
# 3        松山區     中華里           6891.0           6945.0           6919.0
# 4        松山區     東勢里           4790.0           4808.0           4787.0
# ..       ...     ...              ...              ...              ...
# 452      北投區     大同里           6205.0           6266.0           6297.0
# 453      北投區     一德里           7045.0           7225.0           7361.0
# 454      北投區     中央里           9142.0           9210.0           9217.0
# 455      北投區     桃源里           5806.0           5946.0           6128.0
# 456      萬華區     糖?里           5750.0           5764.0           5759.0
#
#      population_2014  population_2015
# 0            10218.0          10218.0
# 1            11219.0          11219.0
# 2             6615.0           6615.0
# 3             6894.0           6894.0
# 4             4744.0           4744.0
# ..               ...              ...
# 452           6283.0           6283.0
# 453           7541.0           7541.0
# 454           9251.0           9251.0
# 455           6314.0           6314.0
# 456           5783.0           5783.0
#
# [457 rows x 15 columns]

# %%
df['用電量_2011'] = pd.to_numeric(df['用電量_2011'], errors='coerce')
df['用電量_2012'] = pd.to_numeric(df['用電量_2012'], errors='coerce')
df['用電量_2013'] = pd.to_numeric(df['用電量_2013'], errors='coerce')
df['用電量_2014'] = pd.to_numeric(df['用電量_2014'], errors='coerce')

# %%
df['人均用電量_2011'] = df['用電量_2011'] / df['population_2011']
df['人均用電量_2012'] = df['用電量_2012'] / df['population_2012']
df['人均用電量_2013'] = df['用電量_2013'] / df['population_2013']
df['人均用電量_2014'] = df['用電量_2014'] / df['population_2014']

# %%
df.drop('Unnamed: 0_x', inplace=True, axis=1)
df.drop('Unnamed: 0_y', inplace=True, axis=1)
df.drop('district', inplace=True, axis=1)
df.drop('village', inplace=True, axis=1)
df.to_csv('avg_electricity_aug.csv')

# %%
df.columns
# Out:
# Index(['鄉鎮名稱', '村里名稱', '用電量_2011', '用電量_2012', '用電量_2013', '用電量_2014',
#        'population_2011', 'population_2012', 'population_2013',
#        'population_2014', 'population_2015', '人均用電量_2011', '人均用電量_2012',
#        '人均用電量_2013', '人均用電量_2014'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 鄉鎮名稱                object
# 村里名稱                object
# 用電量_2011           float64
# 用電量_2012           float64
# 用電量_2013           float64
# 用電量_2014           float64
# population_2011    float64
# population_2012    float64
# population_2013    float64
# population_2014    float64
# population_2015    float64
# 人均用電量_2011         float64
# 人均用電量_2012         float64
# 人均用電量_2013         float64
# 人均用電量_2014         float64
# dtype: object
